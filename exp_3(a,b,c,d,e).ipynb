# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanivanitha0-dev/wpt/blob/main/exp_3(a%2Cb%2Cc%2Cd%2Ce).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data={
    'Firstname':['Aryan','Rohan','Riya','Yash','Siddini'],
    'Lastname':['Singh','Agarwal','Shah','Batia','Khan'],
    'Type':['full-time employee','intern','full-time employee','full-time employee','full-time employee'],
    'Department':['administration','technical','administration','technical','technical'],
    'yoe':[2,3,5,7,6],
    'salary':[20000,5000,10000,20000,15000]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Firstname Lastname                Type      Department  yoe  salary
# 0     Aryan    Singh  full-time employee  administration    2   20000
# 1     Rohan  Agarwal              intern       technical    3    5000
# 2      Riya     Shah  full-time employee  administration    5   10000
# 3      Yash    Batia  full-time employee       technical    7   20000
# 4   Siddini     Khan  full-time employee       technical    6   15000

# %%
import pandas as pd
import numpy as np
data={
    'Firstname':['Aryan','Rohan','Riya','Yash','Siddini'],
    'Lastname':['Singh','Agarwal','Shah','Batia','Khan'],
    'Type':['full-time employee','intern','full-time employee','full-time employee','full-time employee'],
    'Department':['administration','technical','administration','technical','technical'],
    'yoe':[2,3,5,7,6],
    'salary':[20000,5000,10000,20000,15000]
}
df=pd.DataFrame(data)
print(df)
table=pd.pivot_table(df,index=['Type','Department'], values='salary', aggfunc=['mean'])
print(table)
# Out:
#   Firstname Lastname                Type      Department  yoe  salary
# 0     Aryan    Singh  full-time employee  administration    2   20000
# 1     Rohan  Agarwal              intern       technical    3    5000
# 2      Riya     Shah  full-time employee  administration    5   10000
# 3      Yash    Batia  full-time employee       technical    7   20000
# 4   Siddini     Khan  full-time employee       technical    6   15000
#                                       mean
#                                     salary
# Type               Department
# full-time employee administration  15000.0
#                    technical       17500.0
# intern             technical        5000.0

# %%
import pandas as pd
import numpy as np
data={
    'Firstname':['Aryan','Rohan','Riya','Yash','Siddini'],
    'Lastname':['Singh','Agarwal','Shah','Batia','Khan'],
    'Type':['full-time employee','intern','full-time employee','full-time employee','full-time employee'],
    'Department':['administration','technical','administration','technical','technical'],
    'yoe':[2,3,5,7,6],
    'salary':[20000,5000,10000,20000,15000]
}
df=pd.DataFrame(data)
print(df)
table1=pd.pivot_table(df,index=['Type'], values='salary', aggfunc=['sum','mean'])
print(table1)
# Out:
#   Firstname Lastname                Type      Department  yoe  salary
# 0     Aryan    Singh  full-time employee  administration    2   20000
# 1     Rohan  Agarwal              intern       technical    3    5000
# 2      Riya     Shah  full-time employee  administration    5   10000
# 3      Yash    Batia  full-time employee       technical    7   20000
# 4   Siddini     Khan  full-time employee       technical    6   15000
#                       sum     mean
#                    salary   salary
# Type
# full-time employee  65000  16250.0
# intern               5000   5000.0

# %%
import pandas as pd
import numpy as np
data={
    'Firstname':['Aryan','Rohan','Riya','Yash','Siddini'],
    'Lastname':['Singh','Agarwal','Shah','Batia','Khan'],
    'Type':['full-time employee','intern','full-time employee','full-time employee','full-time employee'],
    'Department':['administration','technical','administration','technical','technical'],
    'yoe':[2,3,5,7,6],
    'salary':[20000,5000,10000,20000,15000]
}
df=pd.DataFrame(data)
print(df)
table2=pd.pivot_table(df,index=['Type'], values='salary', aggfunc=['count'])
print(table2)
# Out:
#   Firstname Lastname                Type      Department  yoe  salary
# 0     Aryan    Singh  full-time employee  administration    2   20000
# 1     Rohan  Agarwal              intern       technical    3    5000
# 2      Riya     Shah  full-time employee  administration    5   10000
# 3      Yash    Batia  full-time employee       technical    7   20000
# 4   Siddini     Khan  full-time employee       technical    6   15000
#                     count
#                    salary
# Type
# full-time employee      4
# intern                  1

# %%
import pandas as pd
import numpy as np
data={
    'Firstname':['Aryan','Rohan','Riya','Yash','Siddini'],
    'Lastname':['Singh','Agarwal','Shah','Batia','Khan'],
    'Type':['full-time employee','intern','full-time employee','full-time employee','full-time employee'],
    'Department':['administration','technical','administration','technical','technical'],
    'yoe':[2,3,5,7,6],
    'salary':[20000,5000,10000,20000,15000]
}
df=pd.DataFrame(data)
print(df)
table3=pd.pivot_table(df,index=['Type'], values='salary', aggfunc=['std'])
print(table3)
# Out:
#   Firstname Lastname                Type      Department  yoe  salary
# 0     Aryan    Singh  full-time employee  administration    2   20000
# 1     Rohan  Agarwal              intern       technical    3    5000
# 2      Riya     Shah  full-time employee  administration    5   10000
# 3      Yash    Batia  full-time employee       technical    7   20000
# 4   Siddini     Khan  full-time employee       technical    6   15000
#                             std
#                          salary
# Type
# full-time employee  4787.135539
